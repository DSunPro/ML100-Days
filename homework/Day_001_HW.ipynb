# %% [markdown]
# # Sample Code & 作業內容
#
#
# ## 作業1：
#
# 請上 Kaggle, 在 Competitions(https://www.kaggle.com/competitions) 或 Dataset(https://www.kaggle.com/datasets) 中找一組競賽或資料並寫下：
# https://www.kaggle.com/datasnaek/youtube-new
#
# 1. 你選的這組資料為何重要：可以觀察世界各國觀影趨勢，找出目前國內尚未流行的趨勢主題，進而改善頻道主同質性過高的問題
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：資料來源：
#     https://www.youtube.com/feed/trending ，This dataset was collected using the YouTube API.
#
# 3. 蒐集而來的資料型態為何：JSON 格式
#
# 4. 這組資料想解決的問題如何評估：以發燒影片 (https://www.youtube.com/feed/trending) 為例，包含連續劇、新聞報導、知識型短片、音樂及娛樂短片等類型，可以觀察出娛樂主題時數偏短，顯示觀影者分配給娛樂類型的時間較短，不會專注過多的時間在娛樂類型主題。
#
#
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：提升業績：節慶時舉辦行銷活動刺激業績
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：由使用者問卷或 App 收集
#
# 3. 蒐集而來的資料型態為何：可能是 CSV 或者直接進資料庫
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：觀察假期結束後，使用者問卷增加數量並檢視問卷答案
#
#
# ## 作業3：
#
# 請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：ML100 > data資料夾 & ipynb檔
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)
#
# 提交作業請上傳Day_001_HW.ipynb檔案到您的github帳號之後，再提供連結，(作業1.2申論題目可一併寫在HW檔案裡)
#
#
# 提醒：同步Github本機資料夾時，不需將Data一起同步，只需要將作業檔同步即可。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    ans = np.mean((y - y_hat)**2)

    return ans

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
#print(y_hat)
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat) # 均方誤差
MAE = mean_absolute_error(y, y_hat) # 絕對誤差
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 242.455
# The Mean absolute error is 12.528
